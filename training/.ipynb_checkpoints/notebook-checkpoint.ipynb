# %%
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPool2D,Dropout
import matplotlib.pyplot as plt
import tensorflowjs as tfjs

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train),(x_valid, y_valid) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 4s 0us/step
# 11501568/11490434 [==============================] - 4s 0us/step

# %%
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_valid = x_valid.reshape((x_valid.shape[0], 28, 28, 1))
x_train = tf.keras.utils.normalize(x_train, axis=1)
x_valid = tf.keras.utils.normalize(x_valid, axis=1)
y_train = tf.keras.utils.to_categorical(y_train)
y_valid = tf.keras.utils.to_categorical(y_valid)

# %%
model = Sequential()

# %%
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu', input_shape = (28,28,1)))
model.add(Conv2D(filters = 32, kernel_size = (5,5),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(Conv2D(filters = 64, kernel_size = (3,3),padding = 'Same', 
                 activation ='relu'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(256, activation = "relu"))
model.add(Dropout(0.5))
model.add(Dense(10, activation = "softmax"))

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
early_stopping = EarlyStopping(min_delta=.001,
                               restore_best_weights=True,
                               patience=20,
                               verbose=1)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 32)        832
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 28, 28, 32)        25632
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 14, 14, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 3136)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               803072
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 887,530
# Trainable params: 887,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x_train,y_train,
          epochs=1000,
          validation_data=(x_valid, y_valid),
          callbacks=[early_stopping])
# Out:
# Epoch 1/1000
# 1875/1875 [==============================] - 15s 5ms/step - loss: 0.1829 - accuracy: 0.9431 - val_loss: 0.0383 - val_accuracy: 0.9877
# Epoch 2/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0694 - accuracy: 0.9797 - val_loss: 0.0325 - val_accuracy: 0.9894
# Epoch 3/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0536 - accuracy: 0.9834 - val_loss: 0.0287 - val_accuracy: 0.9910
# Epoch 4/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0441 - accuracy: 0.9870 - val_loss: 0.0229 - val_accuracy: 0.9926
# Epoch 5/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0379 - accuracy: 0.9888 - val_loss: 0.0251 - val_accuracy: 0.9937
# Epoch 6/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0347 - accuracy: 0.9894 - val_loss: 0.0248 - val_accuracy: 0.9929
# Epoch 7/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0319 - accuracy: 0.9899 - val_loss: 0.0199 - val_accuracy: 0.9942
# Epoch 8/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0274 - accuracy: 0.9918 - val_loss: 0.0202 - val_accuracy: 0.9942
# Epoch 9/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0269 - accuracy: 0.9917 - val_loss: 0.0166 - val_accuracy: 0.9952
# Epoch 10/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0282 - accuracy: 0.9916 - val_loss: 0.0202 - val_accuracy: 0.9939
# Epoch 11/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0244 - accuracy: 0.9923 - val_loss: 0.0217 - val_accuracy: 0.9949
# Epoch 12/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0226 - accuracy: 0.9928 - val_loss: 0.0234 - val_accuracy: 0.9934
# Epoch 13/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0231 - accuracy: 0.9929 - val_loss: 0.0216 - val_accuracy: 0.9941
# Epoch 14/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0230 - accuracy: 0.9931 - val_loss: 0.0228 - val_accuracy: 0.9951
# Epoch 15/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0202 - accuracy: 0.9939 - val_loss: 0.0275 - val_accuracy: 0.9930
# Epoch 16/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 0.0218 - val_accuracy: 0.9938
# Epoch 17/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0201 - accuracy: 0.9942 - val_loss: 0.0220 - val_accuracy: 0.9934
# Epoch 18/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0192 - accuracy: 0.9942 - val_loss: 0.0185 - val_accuracy: 0.9950
# Epoch 19/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0190 - accuracy: 0.9942 - val_loss: 0.0252 - val_accuracy: 0.9937
# Epoch 20/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0188 - accuracy: 0.9943 - val_loss: 0.0229 - val_accuracy: 0.9944
# Epoch 21/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0194 - accuracy: 0.9943 - val_loss: 0.0189 - val_accuracy: 0.9943
# Epoch 22/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0176 - accuracy: 0.9945 - val_loss: 0.0254 - val_accuracy: 0.9937
# Epoch 23/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0204 - accuracy: 0.9940 - val_loss: 0.0226 - val_accuracy: 0.9950
# Epoch 24/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0169 - accuracy: 0.9948 - val_loss: 0.0225 - val_accuracy: 0.9946
# Epoch 25/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0215 - accuracy: 0.9939 - val_loss: 0.0222 - val_accuracy: 0.9947
# Epoch 26/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0189 - accuracy: 0.9945 - val_loss: 0.0218 - val_accuracy: 0.9950
# Epoch 27/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0185 - accuracy: 0.9949 - val_loss: 0.0204 - val_accuracy: 0.9938
# Epoch 28/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0177 - accuracy: 0.9949 - val_loss: 0.0281 - val_accuracy: 0.9938
# Epoch 29/1000
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0173 - accuracy: 0.9950 - val_loss: 0.0266 - val_accuracy: 0.9943
# Restoring model weights from the end of the best epoch.
# Epoch 00029: early stopping

# %%
model.evaluate(x_valid, y_valid)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0166 - accuracy: 0.9952
# [0.016630304977297783, 0.995199978351593]

# %%
plt.figure(figsize = (20, 8))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.figure(figsize = (20, 8))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
model.save('python_result.model')
# Out:
# INFO:tensorflow:Assets written to: python_result.model/assets

# %%
tfjs.converters.save_keras_model(model, 'tfjs-model')
